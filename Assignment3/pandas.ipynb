# %%
1. Create a Pandas series with the following data: {'apples': 3, 'bananas': 2, 'oranges': 1}. Then, add
a new item to the series with the key 'pears' and the value 4. (Score: 2)
2. 2. Create a dataframe with the following columns: name, age, and gender. The dataframe should
have 10 rows of data. (Score: 2)
3. 3. Add a new column to the data frame created in question 1, called occupation. The values for
this column should be Programmer, Manager, and Analyst, corresponding to the rows in the
dataframe. (Score: 2)
4. 4. Select the rows of the dataframe where the age is greater than or equal to 30. (Score: 1)
5. 5. Convert this dataframe to a CSV file and read that CSV file, finally display the contents. (Score:
2) Score 1 for timely submission.

# %%
import pandas as pd

s = pd.Series({'apples': 3, 'bananas': 2, 'oranges': 1})

s['pears'] = 4

print(s)
# Out:
# apples     3
# bananas    2
# oranges    1
# pears      4
# dtype: int64

# %%
data = {
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma', 'Frank', 'Grace', 'Helen', 'Ian', 'Julia'],
    'age': [25, 30, 28, 35, 22, 40, 26, 31, 29, 33],
    'gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'M', 'F']
}

df = pd.DataFrame(data)

print(df)
# Out:
#       name  age gender
# 0    Alice   25      F
# 1      Bob   30      M
# 2  Charlie   28      M
# 3    David   35      M
# 4     Emma   22      F
# 5    Frank   40      M
# 6    Grace   26      F
# 7    Helen   31      F
# 8      Ian   29      M
# 9    Julia   33      F

# %%
df['occupation'] = [
    'Programmer', 'Manager', 'Analyst',
    'Programmer', 'Manager', 'Analyst',
    'Programmer', 'Manager', 'Analyst', 'Programmer'
]

print(df)
# Out:
#       name  age gender  occupation
# 0    Alice   25      F  Programmer
# 1      Bob   30      M     Manager
# 2  Charlie   28      M     Analyst
# 3    David   35      M  Programmer
# 4     Emma   22      F     Manager
# 5    Frank   40      M     Analyst
# 6    Grace   26      F  Programmer
# 7    Helen   31      F     Manager
# 8      Ian   29      M     Analyst
# 9    Julia   33      F  Programmer

# %%
age_filtered = df[df['age'] >= 30]

print(age_filtered)
# Out:
#     name  age gender  occupation
# 1    Bob   30      M     Manager
# 3  David   35      M  Programmer
# 5  Frank   40      M     Analyst
# 7  Helen   31      F     Manager
# 9  Julia   33      F  Programmer

# %%
df.to_csv('output_data.csv', index=False)

df_loaded = pd.read_csv('output_data.csv')

print(df_loaded)
# Out:
#       name  age gender  occupation
# 0    Alice   25      F  Programmer
# 1      Bob   30      M     Manager
# 2  Charlie   28      M     Analyst
# 3    David   35      M  Programmer
# 4     Emma   22      F     Manager
# 5    Frank   40      M     Analyst
# 6    Grace   26      F  Programmer
# 7    Helen   31      F     Manager
# 8      Ian   29      M     Analyst
# 9    Julia   33      F  Programmer
