# %%
text = """NOIDA: Investigators probing Nikki Bhati's death have decided to re-examine her sister Kanchan — whose account forms the basis of murder charges against Nikki's husband and in-laws — to establish the chain of events on Aug 21 evening that led to her death.
Five days into the probe, police have no clear answers amid a maze of conflicting claims and social media videos. Seen initially as a case of husband Vipin attacking Nikki, police said the emergence of new videos makes other scenarios plausible and questioning Kanchan was critical to it."""

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\shafeenausman\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sentences = sent_tokenize(text)

# %%
sentences
# Out:
# ["NOIDA: Investigators probing Nikki Bhati's death have decided to re-examine her sister Kanchan — whose account forms the basis of murder charges against Nikki's husband and in-laws — to establish the chain of events on Aug 21 evening that led to her death.",
#  'Five days into the probe, police have no clear answers amid a maze of conflicting claims and social media videos.',
#  'Seen initially as a case of husband Vipin attacking Nikki, police said the emergence of new videos makes other scenarios plausible and questioning Kanchan was critical to it.']

# %%
len(sentences)
# Out:
# 3

# %%
words = word_tokenize(text)

# %%
words
# Out:
# ['NOIDA',
#  ':',
#  'Investigators',
#  'probing',
#  'Nikki',
#  'Bhati',
#  "'s",
#  'death',
#  'have',
#  'decided',
#  'to',
#  're-examine',
#  'her',
#  'sister',
#  'Kanchan',
#  '—',
#  'whose',
#  'account',
#  'forms',
#  'the',
#  'basis',
#  'of',
#  'murder',
#  'charges',
#  'against',
#  'Nikki',
#  "'s",
#  'husband',
#  'and',
#  'in-laws',
#  '—',
#  'to',
#  'establish',
#  'the',
#  'chain',
#  'of',
#  'events',
#  'on',
#  'Aug',
#  '21',
#  'evening',
#  'that',
#  'led',
#  'to',
#  'her',
#  'death',
#  '.',
#  'Five',
#  'days',
#  'into',
#  'the',
#  'probe',
#  ',',
#  'police',
#  'have',
#  'no',
#  'clear',
#  'answers',
#  'amid',
#  'a',
#  'maze',
#  'of',
#  'conflicting',
#  'claims',
#  'and',
#  'social',
#  'media',
#  'videos',
#  '.',
#  'Seen',
#  'initially',
#  'as',
#  'a',
#  'case',
#  'of',
#  'husband',
#  'Vipin',
#  'attacking',
#  'Nikki',
#  ',',
#  'police',
#  'said',
#  'the',
#  'emergence',
#  'of',
#  'new',
#  'videos',
#  'makes',
#  'other',
#  'scenarios',
#  'plausible',
#  'and',
#  'questioning',
#  'Kanchan',
#  'was',
#  'critical',
#  'to',
#  'it',
#  '.']

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shafeenausman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
words_after_stopwords_removal = []
stop_word = []
for word in words:
    if word not in stopwords.words('english'):
        words_after_stopwords_removal.append(word)
    else:
        stop_word.append(word)

# %%
stop_word
# Out:
# ['have',
#  'to',
#  'her',
#  'the',
#  'of',
#  'against',
#  'and',
#  'to',
#  'the',
#  'of',
#  'on',
#  'that',
#  'to',
#  'her',
#  'into',
#  'the',
#  'have',
#  'no',
#  'a',
#  'of',
#  'and',
#  'as',
#  'a',
#  'of',
#  'the',
#  'of',
#  'other',
#  'and',
#  'was',
#  'to',
#  'it']

# %%
words_after_stopwords_removal
# Out:
# ['NOIDA',
#  ':',
#  'Investigators',
#  'probing',
#  'Nikki',
#  'Bhati',
#  "'s",
#  'death',
#  'decided',
#  're-examine',
#  'sister',
#  'Kanchan',
#  '—',
#  'whose',
#  'account',
#  'forms',
#  'basis',
#  'murder',
#  'charges',
#  'Nikki',
#  "'s",
#  'husband',
#  'in-laws',
#  '—',
#  'establish',
#  'chain',
#  'events',
#  'Aug',
#  '21',
#  'evening',
#  'led',
#  'death',
#  '.',
#  'Five',
#  'days',
#  'probe',
#  ',',
#  'police',
#  'clear',
#  'answers',
#  'amid',
#  'maze',
#  'conflicting',
#  'claims',
#  'social',
#  'media',
#  'videos',
#  '.',
#  'Seen',
#  'initially',
#  'case',
#  'husband',
#  'Vipin',
#  'attacking',
#  'Nikki',
#  ',',
#  'police',
#  'said',
#  'emergence',
#  'new',
#  'videos',
#  'makes',
#  'scenarios',
#  'plausible',
#  'questioning',
#  'Kanchan',
#  'critical',
#  '.']

# %%
from nltk.stem import PorterStemmer

# %%
pstem = PorterStemmer()

# %%
for word in words_after_stopwords_removal:
    root_word = pstem.stem(word)
    print("org word:",word, " root word:",root_word)
# Out:
# org word: NOIDA  root word: noida
# org word: :  root word: :
# org word: Investigators  root word: investig
# org word: probing  root word: probe
# org word: Nikki  root word: nikki
# org word: Bhati  root word: bhati
# org word: 's  root word: 's
# org word: death  root word: death
# org word: decided  root word: decid
# org word: re-examine  root word: re-examin
# org word: sister  root word: sister
# org word: Kanchan  root word: kanchan
# org word: —  root word: —
# org word: whose  root word: whose
# org word: account  root word: account
# org word: forms  root word: form
# org word: basis  root word: basi
# org word: murder  root word: murder
# org word: charges  root word: charg
# org word: Nikki  root word: nikki
# org word: 's  root word: 's
# org word: husband  root word: husband
# org word: in-laws  root word: in-law
# org word: —  root word: —
# org word: establish  root word: establish
# org word: chain  root word: chain
# org word: events  root word: event
# org word: Aug  root word: aug
# org word: 21  root word: 21
# org word: evening  root word: even
# org word: led  root word: led
# org word: death  root word: death
# org word: .  root word: .
# org word: Five  root word: five
# org word: days  root word: day
# org word: probe  root word: probe
# org word: ,  root word: ,
# org word: police  root word: polic
# org word: clear  root word: clear
# org word: answers  root word: answer
# org word: amid  root word: amid
# org word: maze  root word: maze
# org word: conflicting  root word: conflict
# org word: claims  root word: claim
# org word: social  root word: social
# org word: media  root word: media
# org word: videos  root word: video
# org word: .  root word: .
# org word: Seen  root word: seen
# org word: initially  root word: initi
# org word: case  root word: case
# org word: husband  root word: husband
# org word: Vipin  root word: vipin
# org word: attacking  root word: attack
# org word: Nikki  root word: nikki
# org word: ,  root word: ,
# org word: police  root word: polic
# org word: said  root word: said
# org word: emergence  root word: emerg
# org word: new  root word: new
# org word: videos  root word: video
# org word: makes  root word: make
# org word: scenarios  root word: scenario
# org word: plausible  root word: plausibl
# org word: questioning  root word: question
# org word: Kanchan  root word: kanchan
# org word: critical  root word: critic
# org word: .  root word: .

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shafeenausman\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
lemmatizer.lemmatize('running',pos='v')
# Out:
# 'run'

# %%
lemmatized_words = [lemmatizer.lemmatize(word) for word in words_after_stopwords_removal]

# %%
lemmatized_words
# Out:
# ['NOIDA',
#  ':',
#  'Investigators',
#  'probing',
#  'Nikki',
#  'Bhati',
#  "'s",
#  'death',
#  'decided',
#  're-examine',
#  'sister',
#  'Kanchan',
#  '—',
#  'whose',
#  'account',
#  'form',
#  'basis',
#  'murder',
#  'charge',
#  'Nikki',
#  "'s",
#  'husband',
#  'in-law',
#  '—',
#  'establish',
#  'chain',
#  'event',
#  'Aug',
#  '21',
#  'evening',
#  'led',
#  'death',
#  '.',
#  'Five',
#  'day',
#  'probe',
#  ',',
#  'police',
#  'clear',
#  'answer',
#  'amid',
#  'maze',
#  'conflicting',
#  'claim',
#  'social',
#  'medium',
#  'video',
#  '.',
#  'Seen',
#  'initially',
#  'case',
#  'husband',
#  'Vipin',
#  'attacking',
#  'Nikki',
#  ',',
#  'police',
#  'said',
#  'emergence',
#  'new',
#  'video',
#  'make',
#  'scenario',
#  'plausible',
#  'questioning',
#  'Kanchan',
#  'critical',
#  '.']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\shafeenausman\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
tagg_words = nltk.pos_tag(words_after_stopwords_removal)
tagg_words
# Out:
# [('NOIDA', 'NN'),
#  (':', ':'),
#  ('Investigators', 'NNS'),
#  ('probing', 'VBG'),
#  ('Nikki', 'NNP'),
#  ('Bhati', 'NNP'),
#  ("'s", 'POS'),
#  ('death', 'NN'),
#  ('decided', 'VBD'),
#  ('re-examine', 'JJ'),
#  ('sister', 'NN'),
#  ('Kanchan', 'NNP'),
#  ('—', 'NNP'),
#  ('whose', 'WP$'),
#  ('account', 'NN'),
#  ('forms', 'JJ'),
#  ('basis', 'NN'),
#  ('murder', 'NN'),
#  ('charges', 'NNS'),
#  ('Nikki', 'NNP'),
#  ("'s", 'POS'),
#  ('husband', 'NN'),
#  ('in-laws', 'JJ'),
#  ('—', 'JJ'),
#  ('establish', 'VB'),
#  ('chain', 'NN'),
#  ('events', 'NNS'),
#  ('Aug', 'VBP'),
#  ('21', 'CD'),
#  ('evening', 'NN'),
#  ('led', 'VBD'),
#  ('death', 'NN'),
#  ('.', '.'),
#  ('Five', 'CD'),
#  ('days', 'NNS'),
#  ('probe', 'NN'),
#  (',', ','),
#  ('police', 'NN'),
#  ('clear', 'JJ'),
#  ('answers', 'NNS'),
#  ('amid', 'IN'),
#  ('maze', 'JJ'),
#  ('conflicting', 'VBG'),
#  ('claims', 'NNS'),
#  ('social', 'JJ'),
#  ('media', 'NNS'),
#  ('videos', 'NNS'),
#  ('.', '.'),
#  ('Seen', 'NNP'),
#  ('initially', 'RB'),
#  ('case', 'NN'),
#  ('husband', 'NN'),
#  ('Vipin', 'NNP'),
#  ('attacking', 'VBG'),
#  ('Nikki', 'NNP'),
#  (',', ','),
#  ('police', 'NN'),
#  ('said', 'VBD'),
#  ('emergence', 'NN'),
#  ('new', 'JJ'),
#  ('videos', 'JJ'),
#  ('makes', 'VBZ'),
#  ('scenarios', 'NNS'),
#  ('plausible', 'JJ'),
#  ('questioning', 'VBG'),
#  ('Kanchan', 'NNP'),
#  ('critical', 'JJ'),
#  ('.', '.')]

# %%
nltk.download('tagsets_json')
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``
# [nltk_data] Downloading package tagsets_json to
# [nltk_data]     C:\Users\shafeenausman\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets_json is already up-to-date!

# %%
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\shafeenausman\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\shafeenausman\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
entities = nltk.ne_chunk(tagg_words)
print(entities)
# Out:
# (S
#   (GPE NOIDA/NN)
#   :/:
#   Investigators/NNS
#   probing/VBG
#   (PERSON Nikki/NNP Bhati/NNP)
#   's/POS
#   death/NN
#   decided/VBD
#   re-examine/JJ
#   sister/NN
#   (PERSON Kanchan/NNP)
#   —/NNP
#   whose/WP$
#   account/NN
#   forms/JJ
#   basis/NN
#   murder/NN
#   charges/NNS
#   (PERSON Nikki/NNP)
#   's/POS
#   husband/NN
#   in-laws/JJ
#   —/JJ
#   establish/VB
#   chain/NN
#   events/NNS
#   Aug/VBP
#   21/CD
#   evening/NN
#   led/VBD
#   death/NN
#   ./.
#   Five/CD
#   days/NNS
#   probe/NN
#   ,/,
#   police/NN
#   clear/JJ
#   answers/NNS
#   amid/IN
#   maze/JJ
#   conflicting/VBG
#   claims/NNS
#   social/JJ
#   media/NNS
#   videos/NNS
#   ./.
#   (PERSON Seen/NNP)
#   initially/RB
#   case/NN
#   husband/NN
#   Vipin/NNP
#   attacking/VBG
#   (PERSON Nikki/NNP)
#   ,/,
#   police/NN
#   said/VBD
#   emergence/NN
#   new/JJ
#   videos/JJ
#   makes/VBZ
#   scenarios/NNS
#   plausible/JJ
#   questioning/VBG
#   (PERSON Kanchan/NNP)
#   critical/JJ
#   ./.)

# %%
for chunk in entities:
    if hasattr(chunk, 'label'):   # Named Entity
        entity_name = " ".join(c[0] for c in chunk)   # Join tokens
        print(entity_name)
        entity_type = chunk.label()                   # PERSON / ORG / GPE / etc
        print(f"{entity_name} --> {entity_type}")
# Out:
# NOIDA
# NOIDA --> GPE
# Nikki Bhati
# Nikki Bhati --> PERSON
# Kanchan
# Kanchan --> PERSON
# Nikki
# Nikki --> PERSON
# Seen
# Seen --> PERSON
# Nikki
# Nikki --> PERSON
# Kanchan
# Kanchan --> PERSON

# %%
import spacy

# Load English NLP model
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[32], line 4
#       1 import spacy
#       3 # Load English NLP model
# ----> 4 nlp = spacy.load("en_core_web_sm")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spacy\__init__.py:52, in load(name, vocab, disable, enable, exclude, config)
#      28 def load(
#      29     name: Union[str, Path],
#      30     *,
#    (...)     35     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      36 ) -> Language:
#      37     """Load a spaCy model from an installed package or a local path.
#      38
#      39     name (str): Package name or model path.
#    (...)     50     RETURNS (Language): The loaded nlp object.
#      51     """
# ---> 52     return util.load_model(
#      53         name,
#      54         vocab=vocab,
#      55         disable=disable,
#      56         enable=enable,
#      57         exclude=exclude,
#      58         config=config,
#      59     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spacy\util.py:531, in load_model(name, vocab, disable, enable, exclude, config)
#     529 if name in OLD_MODEL_SHORTCUTS:
#     530     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 531 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
text = "Apple is looking at buying a startup in India for $1 billion."

# Process text
doc = nlp(text)

for token in doc:
    print(
        token.text,
        token.pos_,
        token.tag_,
        token.lemma_,
        token.is_stop
    )

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
print("Model loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[31], line 2
#       1 import spacy
# ----> 2 nlp = spacy.load("en_core_web_sm")
#       3 print("Model loaded successfully!")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spacy\__init__.py:52, in load(name, vocab, disable, enable, exclude, config)
#      28 def load(
#      29     name: Union[str, Path],
#      30     *,
#    (...)     35     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      36 ) -> Language:
#      37     """Load a spaCy model from an installed package or a local path.
#      38
#      39     name (str): Package name or model path.
#    (...)     50     RETURNS (Language): The loaded nlp object.
#      51     """
# ---> 52     return util.load_model(
#      53         name,
#      54         vocab=vocab,
#      55         disable=disable,
#      56         enable=enable,
#      57         exclude=exclude,
#      58         config=config,
#      59     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\spacy\util.py:531, in load_model(name, vocab, disable, enable, exclude, config)
#     529 if name in OLD_MODEL_SHORTCUTS:
#     530     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 531 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.
